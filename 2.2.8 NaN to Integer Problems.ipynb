# %%
# Import packages with standard conventions
import numpy as np
import pandas as pd

# %%
# Read the CSV file with Pandas
movies = pd.read_excel('movies.xlsx')

# View the DataFrame
movies
# Out:
#                                 Title  Year  Age  IMDb  Rotten Tomatoes  \
# 0                           Inception  2010  13+   8.8             0.87
# 1                          The Matrix  1999  18+   8.7             0.87
# 2              Avengers: Infinity War  2018  13+   8.5             0.84
# 3                  Back to the Future  1985   7+   8.5             0.96
# 4      The Good, the Bad and the Ugly  1966  18+   8.8             0.97
# ...                               ...   ...  ...   ...              ...
# 16739       The Ghosts of Buxley Hall  1980  NaN   6.2              NaN
# 16740                  The Poof Point  2001   7+   4.7              NaN
# 16741           Sharks of Lost Island  2013  NaN   5.7              NaN
# 16742              Man Among Cheetahs  2017  NaN   6.6              NaN
# 16743                In Beaver Valley  1950  NaN   NaN              NaN
#
#                             Directors                            Genres  \
# ...

# %%
movies_na = movies[movies.isna().any(axis=1)]

movies_na.shape
movies_na.tail()
# Out:
#                            Title  Year  Age  IMDb  Rotten Tomatoes  \
# 16739  The Ghosts of Buxley Hall  1980  NaN   6.2              NaN
# 16740             The Poof Point  2001   7+   4.7              NaN
# 16741      Sharks of Lost Island  2013  NaN   5.7              NaN
# 16742         Man Among Cheetahs  2017  NaN   6.6              NaN
# 16743           In Beaver Valley  1950  NaN   NaN              NaN
#
#                   Directors                        Genres        Country  \
# 16739          Bruce Bilson  Comedy,Family,Fantasy,Horror  United States
# 16740           Neal Israel          Comedy,Family,Sci-Fi  United States
# 16741          Neil Gelinas                   Documentary  United States
# 16742  Richard Slater-Jones                   Documentary  United States
# 16743           James Algar      Documentary,Short,Family  United States
#
#       Language  Runtime
# 16739  English    120.0
# 16740  English     90.0
# 16741  English      NaN
# ...

# %%
movies_na = movies[movies.isna().any(axis=1)]

movies_na.shape
# Out:
# (13443, 10)

# %%
movies['Age'].isnull().sum()
# Out:
# 9390

# %%
print(movies.dtypes)

#movies['Age'].fillna(movies['Age'].mean(),inplace=True)
# Out:
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes    float64
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# dtype: object

# %%
movies['Age'][movies['Age'].isna()] = 'Others'
# Out:
# /var/folders/td/h_nv_xmx2dj31ym4jqxrtjs00000gn/T/ipykernel_7753/4134362043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['Age'][movies['Age'].isna()] = 'Others'

# %%
movies['Directors'][movies['Directors'].isna()] = 'Others'
# Out:
# /var/folders/td/h_nv_xmx2dj31ym4jqxrtjs00000gn/T/ipykernel_7753/888079883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['Directors'][movies['Directors'].isna()] = 'Others'

# %%
movies['Country'][movies['Country'].isna()] = 'Others'
# Out:
# /var/folders/td/h_nv_xmx2dj31ym4jqxrtjs00000gn/T/ipykernel_7753/2272082801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['Country'][movies['Country'].isna()] = 'Others'

# %%
movies['Language'][movies['Language'].isna()] = 'Others'
# Out:
# /var/folders/td/h_nv_xmx2dj31ym4jqxrtjs00000gn/T/ipykernel_7753/1244501005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['Language'][movies['Language'].isna()] = 'Others'

# %%
movies['Rotten Tomatoes'].isnull().sum()
# Out:
# 11586

# %%
# Read the CSV file with Pandas
ott = pd.read_csv('ott.csv')

# View the DataFrame
ott
# Out:
#           ID  Netflix  Hulu  Prime Video  Disney+
# 0          1        0     0            1        0
# 1          2        0     1            0        0
# 2          3        0     0            1        0
# 3          4        1     0            0        0
# 4          5        0     0            1        0
# ...      ...      ...   ...          ...      ...
# 16739  16740        0     0            1        0
# 16740  16741        0     0            1        0
# 16741  16742        0     0            1        0
# 16742  16743        0     0            1        0
# 16743  16744        1     0            0        0
#
# [16744 rows x 5 columns]

# %%
movies.shape
# Out:
# (16744, 10)

# %%
movies.dtypes
# Out:
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes    float64
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# dtype: object

# %%
# Column names of data set.
my_list = movies.columns.values.tolist()
my_list
# Out:
# ['Title',
#  'Year',
#  'Age',
#  'IMDb',
#  'Rotten Tomatoes',
#  'Directors',
#  'Genres',
#  'Country',
#  'Language',
#  'Runtime']

# %%
# Read the CSV file with Pandas create a copy movies_num
movies_num = pd.read_excel('movies.xlsx')

# View the DataFrame
movies_num
# Out:
#                                 Title  Year  Age  IMDb  Rotten Tomatoes  \
# 0                           Inception  2010  13+   8.8             0.87
# 1                          The Matrix  1999  18+   8.7             0.87
# 2              Avengers: Infinity War  2018  13+   8.5             0.84
# 3                  Back to the Future  1985   7+   8.5             0.96
# 4      The Good, the Bad and the Ugly  1966  18+   8.8             0.97
# ...                               ...   ...  ...   ...              ...
# 16739       The Ghosts of Buxley Hall  1980  NaN   6.2              NaN
# 16740                  The Poof Point  2001   7+   4.7              NaN
# 16741           Sharks of Lost Island  2013  NaN   5.7              NaN
# 16742              Man Among Cheetahs  2017  NaN   6.6              NaN
# 16743                In Beaver Valley  1950  NaN   NaN              NaN
#
#                             Directors                            Genres  \
# ...

# %%
movies_num.select_dtypes('number')
# Out:
#        Year  IMDb  Rotten Tomatoes  Runtime
# 0      2010   8.8             0.87    148.0
# 1      1999   8.7             0.87    136.0
# 2      2018   8.5             0.84    149.0
# 3      1985   8.5             0.96    116.0
# 4      1966   8.8             0.97    161.0
# ...     ...   ...              ...      ...
# 16739  1980   6.2              NaN    120.0
# 16740  2001   4.7              NaN     90.0
# 16741  2013   5.7              NaN      NaN
# 16742  2017   6.6              NaN      NaN
# 16743  1950   NaN              NaN     32.0
#
# [16744 rows x 4 columns]

# %%
movies.select_dtypes('number')
# Out:
#        Year  IMDb  Rotten Tomatoes  Runtime
# 0      2010   8.8             0.87    148.0
# 1      1999   8.7             0.87    136.0
# 2      2018   8.5             0.84    149.0
# 3      1985   8.5             0.96    116.0
# 4      1966   8.8             0.97    161.0
# ...     ...   ...              ...      ...
# 16739  1980   6.2              NaN    120.0
# 16740  2001   4.7              NaN     90.0
# 16741  2013   5.7              NaN      NaN
# 16742  2017   6.6              NaN      NaN
# 16743  1950   NaN              NaN     32.0
#
# [16744 rows x 4 columns]

# %%
# Just replace all missing values with 0 since they are numeric.
movies_num[movies_num.isna().any(axis=1)]
# Out:
#                            Title  Year  Age  IMDb  Rotten Tomatoes  \
# 32                Train to Busan  2016  NaN   7.5             0.94
# 57                A Silent Voice  2016  NaN   8.2             0.94
# 58                   Snowpiercer  2013  18+   7.1             0.94
# 80                  Philadelphia  1993  13+   7.7             0.80
# 89                 The Dawn Wall  2018  NaN   8.1             1.00
# ...                          ...   ...  ...   ...              ...
# 16739  The Ghosts of Buxley Hall  1980  NaN   6.2              NaN
# 16740             The Poof Point  2001   7+   4.7              NaN
# 16741      Sharks of Lost Island  2013  NaN   5.7              NaN
# 16742         Man Among Cheetahs  2017  NaN   6.6              NaN
# 16743           In Beaver Valley  1950  NaN   NaN              NaN
#
#                         Directors                          Genres  \
# 32                   Sang-ho Yeon          Action,Horror,Thriller
# ...

# %%
# remove all Year column
movies_num.drop(['Year'], axis=1)
# Out:
#                                 Title  Age  IMDb  Rotten Tomatoes  \
# 0                           Inception  13+   8.8             0.87
# 1                          The Matrix  18+   8.7             0.87
# 2              Avengers: Infinity War  13+   8.5             0.84
# 3                  Back to the Future   7+   8.5             0.96
# 4      The Good, the Bad and the Ugly  18+   8.8             0.97
# ...                               ...  ...   ...              ...
# 16739       The Ghosts of Buxley Hall  NaN   6.2              NaN
# 16740                  The Poof Point   7+   4.7              NaN
# 16741           Sharks of Lost Island  NaN   5.7              NaN
# 16742              Man Among Cheetahs  NaN   6.6              NaN
# 16743                In Beaver Valley  NaN   NaN              NaN
#
#                             Directors                            Genres  \
# 0                   Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
# calculate Q1 and Q3 for all numeric 
q1 = movies_num.quantile(0.25)
q3 = movies_num.quantile(0.75)
print(q1)
print(q3)
# Out:
# Year               2000.00
# IMDb                  5.10
# Rotten Tomatoes       0.44
# Runtime              82.00
# Name: 0.25, dtype: float64
# Year               2016.00
# IMDb                  6.90
# Rotten Tomatoes       0.88
# Runtime             104.00
# Name: 0.75, dtype: float64

# %%
# calculate the IQR.
iqr = q3 - q1
print(iqr)
# Out:
# Year               16.00
# IMDb                1.80
# Rotten Tomatoes     0.44
# Runtime            22.00
# dtype: float64

# %%
# use describe() method.
movies_num['Rotten Tomatoes'].mean()
# Out:
# 0.6542846064366074

# %%
movies['Rotten Tomatoes'].isnull().sum()
# Out:
# 11586

# %%
movies['Rotten Tomatoes'].fillna(movies['Rotten Tomatoes'].mean(),inplace=True)

# %%
movies['Rotten Tomatoes'].isnull().sum()
# Out:
# 0

# %%
movies['Rotten Tomatoes'] = movies['Rotten Tomatoes'].astype(object).astype(int)

# %%
movies.dtypes
# Out:
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes      int64
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# dtype: object
