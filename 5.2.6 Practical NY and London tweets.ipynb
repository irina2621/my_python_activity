# %%
# Copy the YAML file and your Twitter keys over before you start to work.
import yaml
from yaml.loader import SafeLoader
from twitter import *

# Import the YAML file – remember to specify the whole path.
twitter_creds = yaml.safe_load(open('twitter.yaml', 'r').read())

# Pass your Twitter credentials.
twitter_api = Twitter(auth=OAuth(twitter_creds['access_token'],
                                 twitter_creds['access_token_secret'], 
                                 twitter_creds['api_key'],
                                 twitter_creds['api_secret_key'] ))

# %%
twitter_creds.keys()
# Out:
# dict_keys(['api_key', 'api_secret_key', 'access_token', 'access_token_secret'])

# %%
# Check your connection to the API. Confirm the connection with the #python search.
python_tweets = twitter_api.search.tweets(q='#python')
print(python_tweets)
# Out:
# {'statuses': [{'created_at': 'Thu Oct 13 16:33:11 +0000 2022', 'id': 1580597529921867778, 'id_str': '1580597529921867778', 'text': 'Python QA #MachineLearning #DataScience #SQL #Cybersecurity #BigData #Analytics #AI #IIoT #Python #RStats… https://t.co/4vnWKXnh01', 'truncated': True, 'entities': {'hashtags': [{'text': 'MachineLearning', 'indices': [10, 26]}, {'text': 'DataScience', 'indices': [27, 39]}, {'text': 'SQL', 'indices': [40, 44]}, {'text': 'Cybersecurity', 'indices': [45, 59]}, {'text': 'BigData', 'indices': [60, 68]}, {'text': 'Analytics', 'indices': [69, 79]}, {'text': 'AI', 'indices': [80, 83]}, {'text': 'IIoT', 'indices': [84, 89]}, {'text': 'Python', 'indices': [90, 97]}, {'text': 'RStats', 'indices': [98, 105]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/4vnWKXnh01', 'expanded_url': 'https://twitter.com/i/web/status/1580597529921867778', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [107, 130]}]}, 'metadata': {'iso_language_code': 'cy', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1397152091122982922, 'id_str': '1397152091122982922', 'name': 'Samarpita', 'screen_name': 'iamsimuna', 'location': ' India', 'description': '🇮🇳 l Learning Computer  Programming, Web development ⭐ , Started my blog https://t.co/fnKt9E6tht🎉🔥 | https://t.co/LFhb4GGOXX', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/fnKt9E6tht', 'expanded_url': 'http://tina.hashnode.dev', 'display_url': 'tina.hashnode.dev', 'indices': [73, 96]}, {'url': 'https://t.co/LFhb4GGOXX', 'expanded_url': 'http://instagram.com/tinaworld360/', 'display_url': 'instagram.com/tinaworld360/', 'indices': [101, 124]}]}}, 'protected': False, 'followers_count': 1347, 'friends_count': 2041, 'listed_count': 22, 'created_at': 'Tue May 25 11:26:49 +0000 2021', 'favourites_count': 854, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 697, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1398889693542899714/vGK-TDIL_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1398889693542899714/vGK-TDIL_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1397152091122982922/1622268513', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'cy'}, {'created_at': 'Thu Oct 13 16:33:11 +0000 2022', 'id': 1580597527014912000, 'id_str': '1580597527014912000', 'text': 'RT @martinhoyes: #GoogleCloudNext #startups #startup #GoogleCloud https://t.co/QzkbL92wBW https://t.co/gdynoADjCv https://t.co/BPjQ2y3fyR h…', 'truncated': False, 'entities': {'hashtags': [{'text': 'GoogleCloudNext', 'indices': [17, 33]}, {'text': 'startups', 'indices': [34, 43]}, {'text': 'startup', 'indices': [44, 52]}, {'text': 'GoogleCloud', 'indices': [53, 65]}], 'symbols': [], 'user_mentions': [{'screen_name': 'martinhoyes', 'name': 'martin hoyes', 'id': 780292093839220736, 'id_str': '780292093839220736', 'indices': [3 ...

# %%
# Identify worldwide trends.
trends_worldwide = twitter_api.trends.available()

# Identify the number of available trends.
print(len(trends_worldwide))

# Example of trends_worldwide.
trends_worldwide[0]
# Out:
# 467
# {'name': 'Worldwide',
#  'placeType': {'code': 19, 'name': 'Supername'},
#  'url': 'http://where.yahooapis.com/v1/place/1',
#  'parentid': 0,
#  'country': '',
#  'woeid': 1,
#  'countryCode': None}

# %%
# Search trends worldwide for the IDs of the required cities (US as New York and UK as London).
# Find New York.
our_city = 'New York'

# Create a variable.
list_of_names_our_city = [_ for _ in trends_worldwide if _['name'] == our_city]

# View the output.
print(len(list_of_names_our_city))

# Use index to find New York.
list_of_names_our_city[0]
# Out:
# 1
# {'name': 'New York',
#  'placeType': {'code': 7, 'name': 'Town'},
#  'url': 'http://where.yahooapis.com/v1/place/2459115',
#  'parentid': 23424977,
#  'country': 'United States',
#  'woeid': 2459115,
#  'countryCode': 'US'}

# %%
# List of 'where on earth identifiers' (woeid)
list_of_names_our_city[0]['woeid']
# Out:
# 2459115

# %%
# Look at common trends in Moscow.
ny_trends = twitter_api.trends.place(_id = list_of_names_our_city[0]['woeid'])

# View the output.
ny_trends
# Out:
# [{'trends': [{'name': 'Sabres',
#     'url': 'http://twitter.com/search?q=Sabres',
#     'promoted_content': None,
#     'query': 'Sabres',
#     'tweet_volume': None},
#    {'name': 'Cartoon Network',
#     'url': 'http://twitter.com/search?q=%22Cartoon+Network%22',
#     'promoted_content': None,
#     'query': '%22Cartoon+Network%22',
#     'tweet_volume': 109623},
#    {'name': 'Parkland',
#     'url': 'http://twitter.com/search?q=Parkland',
#     'promoted_content': None,
#     'query': 'Parkland',
#     'tweet_volume': 33294},
#    {'name': '#AMAs',
#     'url': 'http://twitter.com/search?q=%23AMAs',
#     'promoted_content': None,
#     'query': '%23AMAs',
#     'tweet_volume': 1017639},
#    {'name': 'Dan Snyder',
#     'url': 'http://twitter.com/search?q=%22Dan+Snyder%22',
#     'promoted_content': None,
#     'query': '%22Dan+Snyder%22',
#     'tweet_volume': None},
#    {'name': '#SheHulk',
#     'url': 'http://twitter.com/search?q=%23SheHulk',
#     'promoted_content': None,
#     'query': '%23SheHulk',
#     'tweet_volume': 95434},
#    {'name': 'Nikolas Cruz',
#     'url': 'http://twitter.com/search?q=%22Nikolas+Cruz%22',
#     'promoted_content': None,
#     'query': '%22Nikolas+Cruz%22',
#     'tweet_volume': 11660},
#    {'name': '#PaulSilva',
#     'url': 'http://twitter.com/search?q=%23PaulSilva',
#     'promoted_content': None,
#     'query': '%23PaulSilva',
#     'tweet_volume': None},
#    {'name': '#thursdayvibes',
#     'url': 'http://twitter.com/search?q=%23thursdayvibes',
#     'promoted_content': None,
#     'query': '%23thursdayvibes',
#     'tweet_volume': 12526},
#    {'name': 'Voting for a Republican',
#     'url': 'http://twitter.com/search?q=%22Voting+for+a+Republican%22',
#     'promoted_content': None,
#     'query': '%22Voting+for+a+Republican%22',
#     'tweet_volume': None},
#    {'name': '#inflation',
#     'url': 'http://twitter.com/search?q=%23inflation',
#     'promoted_content': None,
#     'query': '%23inflation',
#     'tweet_volume': 19942},
#    {'name': 'Favorite Pop Duo or Group',
#     'url': 'http://twitter.com/search?q=%22Favorite+Pop+Duo+or+Group%22',
#     'promoted_content': None,
#     'query': '%22Favorite+Pop+Duo+or+Group%22',
#     'tweet_volume': 513896},
#    {'name': 'Iraq',
#     'url': 'http://twitter.com/search?q=Iraq',
#     'promoted_content': None,
#     'query': 'Iraq',
#     'tweet_volume': 74273},
#    {'name': 'Social Security',
#     'url': 'http://twitter.com/search?q=%22Social+Security%22',
#     'promoted_content': None,
#     'query': '%22Social+Security%22',
#     'tweet_volume': 118928},
#    {'name': 'Beyoncé and Rihanna',
#     'url': 'http://twitter.com/search?q=%22Beyonc%C3%A9+and+Rihanna%22',
#     'promoted_content': None,
#     'query': '%22Beyonc%C3%A9+and+Rihanna%22',
#     'tweet_volume': None},
#    {'name': 'Ms. Marvel',
#     'url': 'http://twitter.com/search?q=%22Ms.+Marvel%22',
#     'promoted_content': None,
#     'query': '%22Ms.+Marvel%22',
#     'tweet_volume': None},
#    {'name': 'Carlos Correa',
#     'url': 'http://twitter.com/search?q=%22Carlos+Correa%22',
#     'promoted_content': None,
#     'query': '%22Carlos+Correa%22',
#     'tweet_volume': None},
#    {'name': 'Isaiah Joe',
#     'url': 'http://twitter.com/search?q=%22Isaiah+Joe%22',
#     'promoted_content': None,
#     'query': '%22Isaiah+Joe%22',
#     'tweet_volume': None},
#    {'name': 'Death Penalty',
#     'url': 'http://twitter.com/search?q=%22Death+Penalty%22',
#     'promoted_content': None,
#     'query': '%22Death+Penalty%22',
#     'tweet_volume': 20148},
#    {'name': 'Gallardo',
#     'url': 'http://twitter.com/search?q=Gallardo',
#     'promoted_content': None,
#     'query': 'Gallardo',
#     'tweet_volume': 92501},
#    {'name': 'Jerry Jones',
#     'url': 'http://twitter.com/search?q=%22Jerry+Jones%22',
#     'promoted_content': None,
#     'query': '%22Jerry+Jones%22',
#     'tweet_volume': None},
#    {'name': 'Happy 247th',
#     'url': 'http://twitter.com/search?q=%22Happy+247th%22',
#     'promoted_content': None,
#     'query': '%22Happy+247th%22',
#     'tweet_volume': None},
#    {'name': 'Jaspers',
#     'url': 'http://twitter.com/search?q=Jaspers',
#     'promoted_content': None,
#     'query': 'Jaspers',
#     'tweet_volume': None},
#    {'name': 'Goodell',
#     'url': 'http://twitter.com/search?q=Goodell',
#     'promoted_content': None,
#     'query': 'Goodell',
#     'tweet_volume': None},
#    {'name': 'Woodman',
#     'url': 'http://twitter.com/search?q=Woodman',
#     'promoted_content': None,
#     'query': 'Woodman',
#     'tweet_volume': None},
#    {'name': 'Westbrook',
#     'url': 'http://twitter.com/search?q=Westbrook',
#     'promoted_content': None,
#     'query': 'Westbrook',
#     'tweet_volume': 12300},
#    {'name': '$SPY',
#     'url': 'http://twitter.com/search?q=%24SPY',
#     'promoted_content': None,
#     'query': '%24SPY',
#     'tweet_volume': 20469},
#    {'name': 'William Jackson',
#     'url': 'http://twitter.com/search?q=%22William+Jackson%22',
#     'promoted_content': None,
#     'query': '%22William+Jackson%22',
#     'tweet_volume': None},
#    {'name': 'Ginuwine',
#     'url': 'http://twitter.com/search?q=Ginuwine',
#     'promoted_content': None,
#     'query': 'Ginuwine',
#     'tweet_volume': None},
#    {'name': 'Skaar',
#     'url': 'http://twitter.com/search?q=Skaar',
#     'promoted_content': None,
#     'query': 'Skaar',
#     'tweet_volume': None},
#    {'name': 'Life in Prison',
#     'url': 'http://twitter.com/search?q=%22Life+in+Prison%22',
#     'promoted_content': None,
#     'query': '%22Life+in+Prison%22',
#     'tweet_volume': 13256},
#    {'name': 'Macron',
#     'url': 'http://twitter.com/search?q=Macron',
#     'promoted_content': None,
#     'query': 'Macron',
#     'tweet_volume': 189477},
#    {'name': 'Graham Norton',
#     'url': 'http://twitter.com/search?q=%22Graham+Norton%22',
#     'promoted_content': None,
#     'query': '%22Graham+Norton%22',
#     'tweet_volume': 11633},
#    {'name': 'Alex Hamzy',
#     'url': 'http://twitter.com/search?q=%22Alex+Hamzy%22',
#     'promoted_content': None,
#     'query': '%22Alex+Hamzy%22',
#     'tweet_volume': None},
#    {'name': 'Bassey',
#     'url': 'http://twitter.com/search?q=Bassey',
#     'promoted_content': None,
#     'query': 'Bassey',
#     'tweet_volume': None},
#    {'name': 'Nino Brown',
#     'url': 'http://twitter.com/search?q=%22Nino+Brown%22',
#     'promoted_content': None,
#     'query': '%22Nino+Brown%22',
#     'tweet_volume': None},
#    {'name': 'Dan Synder',
#     'url': 'http://twitter.com/search?q=%22Dan+Synder%22',
#     'promoted_content': None,
#     'query': '%22Dan+Synder%22',
#     'tweet_volume': None},
#    {'name': 'Kroger',
#     'url': 'http://twitter.com/search?q=Kroger',
#     'promoted_content': None,
#     'query': 'Kroger',
#     'tweet_volume': None},
#    {'name': 'cheol',
#     'url': 'http://twitter.com/search?q=cheol',
#     'promoted_content': None,
#     'query': 'cheol',
#     'tweet_volume': 31988},
#    {'name': 'Albertsons',
#     'url': 'http://twitter.com/search?q=Albertsons',
#     'promoted_content': None,
#     'query': 'Albertsons',
#     'tweet_volume': None},
#    {'name': 'Happy Friday Eve',
#     'url': 'http://twitter.com/search?q=%22Happy+Friday+Eve%22',
#     'promoted_content': None,
#     'query': '%22Happy+Friday+Eve%22',
#     'tweet_volume': None},
#    {'name': 'COLA',
#     'url': 'http://twitter.com/search?q=COLA',
#     'promoted_content': None,
#     'query': 'COLA',
#     'tweet_volume': 55890},
#    {'name': 'Gohmert',
#     'url': 'http://twitter.com/search?q=Gohmert',
#     'promoted_content': None,
#     'query': 'Gohmert',
#     'tweet_volume': None},
#    {'name': 'Board of Trustees',
#     'url': 'http://twitter.com/search?q=%22Board+of+Trustees%22',
#     'promoted_content': None,
#     'query': '%22Board+of+Trustees%22',
#     'tweet_volume': None},
#    {'name': 'Rittenhouse',
#     'url': 'http://twitter.com/search?q=Rittenhouse',
#     'promoted_content': None,
#     'query': 'Rittenhouse',
#     'tweet_volume': 13198},
#    {'name': 'Trump Organization',
#     'url': 'http://twitter.com/search?q=%22Trump+Organization%22',
#     'promoted_content': None,
#     'query': '%22Trump+Organization%22',
#     'tweet_volume': 14873},
#    {'name': 'Core CPI',
#     'url': 'http://twitter.com/search?q=%22Core+CPI%22',
#     'promoted_content': None,
#     'query': '%22Core+CPI%22',
#     'tweet_volume': 13523},
#    {'name': 'Beau',
#     'url': 'http://twitter.com/search?q=Beau',
#     'promoted_content': None,
#     'query': 'Beau',
#     'tweet_volume': 61773},
#    {'name': 'Thirsty Thursday',
#     'url': 'http://twitter.com/search?q=%22Thirsty+Thursday%22',
#     'promoted_content': None,
#     'query': '%22Thirsty+Thursday%22',
#     'tweet_volume': None},
#    {'name': 'Korkmaz',
#     'url': 'http://twitter.com/search?q=Korkmaz',
#     'promoted_content': None,
#     'query': 'Korkmaz',
#     'tweet_volume': None}],
#   'as_of': '2022-10-13T16:38:51Z',
#   'created_at': '2022-10-09T06:33:23Z',
#   'locations': [{'name': 'New York', 'woeid': 2459115}]}]

# %%
# View output as a DataFrame.
# Import Pandas.
import pandas as pd

# Create a DataFrame.
ny_trends_pd = pd.DataFrame(ny_trends[0]['trends'])

# View the DataFrame.
ny_trends_pd
# Out:
#                          name  \
# 0                      Sabres
# 1             Cartoon Network
# 2                    Parkland
# 3                       #AMAs
# 4                  Dan Snyder
# 5                    #SheHulk
# 6                Nikolas Cruz
# 7                  #PaulSilva
# 8              #thursdayvibes
# 9     Voting for a Republican
# 10                 #inflation
# 11  Favorite Pop Duo or Group
# 12                       Iraq
# 13            Social Security
# 14        Beyoncé and Rihanna
# 15                 Ms. Marvel
# 16              Carlos Correa
# 17                 Isaiah Joe
# 18              Death Penalty
# 19                   Gallardo
# 20                Jerry Jones
# 21                Happy 247th
# 22                    Jaspers
# 23                    Goodell
# 24                    Woodman
# 25                  Westbrook
# 26                       $SPY
# 27            William Jackson
# 28                   Ginuwine
# 29                      Skaar
# 30             Life in Prison
# 31                     Macron
# 32              Graham Norton
# 33                 Alex Hamzy
# 34                     Bassey
# 35                 Nino Brown
# 36                 Dan Synder
# 37                     Kroger
# 38                      cheol
# 39                 Albertsons
# 40           Happy Friday Eve
# 41                       COLA
# 42                    Gohmert
# 43          Board of Trustees
# 44                Rittenhouse
# 45         Trump Organization
# 46                   Core CPI
# 47                       Beau
# 48           Thirsty Thursday
# 49                    Korkmaz
#
#                                                   url promoted_content  \
# 0                  http://twitter.com/search?q=Sabres             None
# 1   http://twitter.com/search?q=%22Cartoon+Network%22             None
# 2                http://twitter.com/search?q=Parkland             None
# 3                 http://twitter.com/search?q=%23AMAs             None
# 4        http://twitter.com/search?q=%22Dan+Snyder%22             None
# 5              http://twitter.com/search?q=%23SheHulk             None
# 6      http://twitter.com/search?q=%22Nikolas+Cruz%22             None
# 7            http://twitter.com/search?q=%23PaulSilva             None
# 8        http://twitter.com/search?q=%23thursdayvibes             None
# 9   http://twitter.com/search?q=%22Voting+for+a+Re...             None
# 10           http://twitter.com/search?q=%23inflation             None
# 11  http://twitter.com/search?q=%22Favorite+Pop+Du...             None
# 12                   http://twitter.com/search?q=Iraq             None
# 13  http://twitter.com/search?q=%22Social+Security%22             None
# 14  http://twitter.com/search?q=%22Beyonc%C3%A9+an...             None
# 15       http://twitter.com/search?q=%22Ms.+Marvel%22             None
# 16    http://twitter.com/search?q=%22Carlos+Correa%22             None
# 17       http://twitter.com/search?q=%22Isaiah+Joe%22             None
# 18    http://twitter.com/search?q=%22Death+Penalty%22             None
# 19               http://twitter.com/search?q=Gallardo             None
# 20      http://twitter.com/search?q=%22Jerry+Jones%22             None
# 21      http://twitter.com/search?q=%22Happy+247th%22             None
# 22                http://twitter.com/search?q=Jaspers             None
# 23                http://twitter.com/search?q=Goodell             None
# 24                http://twitter.com/search?q=Woodman             None
# 25              http://twitter.com/search?q=Westbrook             None
# 26                 http://twitter.com/search?q=%24SPY             None
# 27  http://twitter.com/search?q=%22William+Jackson%22             None
# 28               http://twitter.com/search?q=Ginuwine             None
# 29                  http://twitter.com/search?q=Skaar             None
# 30   http://twitter.com/search?q=%22Life+in+Prison%22             None
# 31                 http://twitter.com/search?q=Macron             None
# 32    http://twitter.com/search?q=%22Graham+Norton%22             None
# 33       http://twitter.com/search?q=%22Alex+Hamzy%22             None
# 34                 http://twitter.com/search?q=Bassey             None
# 35       http://twitter.com/search?q=%22Nino+Brown%22             None
# 36       http://twitter.com/search?q=%22Dan+Synder%22             None
# 37                 http://twitter.com/search?q=Kroger             None
# 38                  http://twitter.com/search?q=cheol             None
# 39             http://twitter.com/search?q=Albertsons             None
# 40  http://twitter.com/search?q=%22Happy+Friday+Ev...             None
# 41                   http://twitter.com/search?q=COLA             None
# 42                http://twitter.com/search?q=Gohmert             None
# 43  http://twitter.com/search?q=%22Board+of+Truste...             None
# 44            http://twitter.com/search?q=Rittenhouse             None
# 45  http://twitter.com/search?q=%22Trump+Organizat...             None
# 46         http://twitter.com/search?q=%22Core+CPI%22             None
# 47                   http://twitter.com/search?q=Beau             None
# 48  http://twitter.com/search?q=%22Thirsty+Thursda...             None
# 49                http://twitter.com/search?q=Korkmaz             None
#
#                               query  tweet_volume
# 0                            Sabres           NaN
# 1             %22Cartoon+Network%22      109623.0
# 2                          Parkland       33294.0
# 3                           %23AMAs     1017639.0
# 4                  %22Dan+Snyder%22           NaN
# 5                        %23SheHulk       95434.0
# 6                %22Nikolas+Cruz%22       11660.0
# 7                      %23PaulSilva           NaN
# 8                  %23thursdayvibes       12526.0
# 9     %22Voting+for+a+Republican%22           NaN
# 10                     %23inflation       19942.0
# 11  %22Favorite+Pop+Duo+or+Group%22      513896.0
# 12                             Iraq       74273.0
# 13            %22Social+Security%22      118928.0
# 14   %22Beyonc%C3%A9+and+Rihanna%22           NaN
# 15                 %22Ms.+Marvel%22           NaN
# 16              %22Carlos+Correa%22           NaN
# 17                 %22Isaiah+Joe%22           NaN
# 18              %22Death+Penalty%22       20148.0
# 19                         Gallardo       92501.0
# 20                %22Jerry+Jones%22           NaN
# 21                %22Happy+247th%22           NaN
# 22                          Jaspers           NaN
# 23                          Goodell           NaN
# 24                          Woodman           NaN
# 25                        Westbrook       12300.0
# 26                           %24SPY       20469.0
# 27            %22William+Jackson%22           NaN
# 28                         Ginuwine           NaN
# 29                            Skaar           NaN
# 30             %22Life+in+Prison%22       13256.0
# 31                           Macron      189477.0
# 32              %22Graham+Norton%22       11633.0
# 33                 %22Alex+Hamzy%22           NaN
# 34                           Bassey           NaN
# 35                 %22Nino+Brown%22           NaN
# 36                 %22Dan+Synder%22           NaN
# 37                           Kroger           NaN
# 38                            cheol       31988.0
# 39                       Albertsons           NaN
# 40           %22Happy+Friday+Eve%22           NaN
# 41                             COLA       55890.0
# 42                          Gohmert           NaN
# 43          %22Board+of+Trustees%22           NaN
# 44                      Rittenhouse       13198.0
# 45         %22Trump+Organization%22       14873.0
# 46                   %22Core+CPI%22       13523.0
# 47                             Beau       61773.0
# 48           %22Thirsty+Thursday%22           NaN
# 49                          Korkmaz           NaN

# %%
# Narrow the list down to 50,000 tweets.
ny_trends_over50k_pd = ny_trends_pd[ny_trends_pd['tweet_volume'] > 50000]\
.sort_values('tweet_volume', ascending=False)

# View the output.
print(ny_trends_over50k_pd.shape)
ny_trends_over50k_pd
# Out:
# (10, 5)
#                          name  \
# 3                       #AMAs
# 11  Favorite Pop Duo or Group
# 31                     Macron
# 13            Social Security
# 1             Cartoon Network
# 5                    #SheHulk
# 19                   Gallardo
# 12                       Iraq
# 47                       Beau
# 41                       COLA
#
#                                                   url promoted_content  \
# 3                 http://twitter.com/search?q=%23AMAs             None
# 11  http://twitter.com/search?q=%22Favorite+Pop+Du...             None
# 31                 http://twitter.com/search?q=Macron             None
# 13  http://twitter.com/search?q=%22Social+Security%22             None
# 1   http://twitter.com/search?q=%22Cartoon+Network%22             None
# 5              http://twitter.com/search?q=%23SheHulk             None
# 19               http://twitter.com/search?q=Gallardo             None
# 12                   http://twitter.com/search?q=Iraq             None
# 47                   http://twitter.com/search?q=Beau             None
# 41                   http://twitter.com/search?q=COLA             None
#
#                               query  tweet_volume
# 3                           %23AMAs     1017639.0
# 11  %22Favorite+Pop+Duo+or+Group%22      513896.0
# 31                           Macron      189477.0
# 13            %22Social+Security%22      118928.0
# 1             %22Cartoon+Network%22      109623.0
# 5                        %23SheHulk       95434.0
# 19                         Gallardo       92501.0
# 12                             Iraq       74273.0
# 47                             Beau       61773.0
# 41                             COLA       55890.0

# %%
# List of 'where on earth identifiers' (woeid)
list_of_names_our_city[0]['woeid']
# Out:
# 44418

# %%
# Find London.
our_city = 'London'

# Create a variable.
list_of_names_our_city = [_ for _ in trends_worldwide if _['name'] == our_city]

# View the output.
print(len(list_of_names_our_city))

# Use index to find London.
list_of_names_our_city[0]
# Out:
# 1
# {'name': 'London',
#  'placeType': {'code': 7, 'name': 'Town'},
#  'url': 'http://where.yahooapis.com/v1/place/44418',
#  'parentid': 23424975,
#  'country': 'United Kingdom',
#  'woeid': 44418,
#  'countryCode': 'GB'}

# %%
# Look at common trends in London.
london_trends = twitter_api.trends.place(_id = list_of_names_our_city[0]['woeid'])

# View the output.
london_trends
# Out:
# [{'trends': [{'name': 'Old Trafford',
#     'url': 'http://twitter.com/search?q=%22Old+Trafford%22',
#     'promoted_content': None,
#     'query': '%22Old+Trafford%22',
#     'tweet_volume': None},
#    {'name': '#construction',
#     'url': 'http://twitter.com/search?q=%23construction',
#     'promoted_content': None,
#     'query': '%23construction',
#     'tweet_volume': None},
#    {'name': 'Channel 4',
#     'url': 'http://twitter.com/search?q=%22Channel+4%22',
#     'promoted_content': None,
#     'query': '%22Channel+4%22',
#     'tweet_volume': 35949},
#    {'name': 'Rangers',
#     'url': 'http://twitter.com/search?q=Rangers',
#     'promoted_content': None,
#     'query': 'Rangers',
#     'tweet_volume': 124944},
#    {'name': 'Alex Jones',
#     'url': 'http://twitter.com/search?q=%22Alex+Jones%22',
#     'promoted_content': None,
#     'query': '%22Alex+Jones%22',
#     'tweet_volume': 600808},
#    {'name': '#ranliv',
#     'url': 'http://twitter.com/search?q=%23ranliv',
#     'promoted_content': None,
#     'query': '%23ranliv',
#     'tweet_volume': 38364},
#    {'name': '#PMQs',
#     'url': 'http://twitter.com/search?q=%23PMQs',
#     'promoted_content': None,
#     'query': '%23PMQs',
#     'tweet_volume': 28907},
#    {'name': 'Barca',
#     'url': 'http://twitter.com/search?q=Barca',
#     'promoted_content': None,
#     'query': 'Barca',
#     'tweet_volume': 404779},
#    {'name': 'Firmino',
#     'url': 'http://twitter.com/search?q=Firmino',
#     'promoted_content': None,
#     'query': 'Firmino',
#     'tweet_volume': 52008},
#    {'name': 'Napoli',
#     'url': 'http://twitter.com/search?q=Napoli',
#     'promoted_content': None,
#     'query': 'Napoli',
#     'tweet_volume': 92238},
#    {'name': '#thursdayvibes',
#     'url': 'http://twitter.com/search?q=%23thursdayvibes',
#     'promoted_content': None,
#     'query': '%23thursdayvibes',
#     'tweet_volume': 12665},
#    {'name': 'Ibrox',
#     'url': 'http://twitter.com/search?q=Ibrox',
#     'promoted_content': None,
#     'query': 'Ibrox',
#     'tweet_volume': 14159},
#    {'name': 'Angela Lansbury',
#     'url': 'http://twitter.com/search?q=%22Angela+Lansbury%22',
#     'promoted_content': None,
#     'query': '%22Angela+Lansbury%22',
#     'tweet_volume': 46998},
#    {'name': 'Goldson',
#     'url': 'http://twitter.com/search?q=Goldson',
#     'promoted_content': None,
#     'query': 'Goldson',
#     'tweet_volume': None},
#    {'name': 'Nuno',
#     'url': 'http://twitter.com/search?q=Nuno',
#     'promoted_content': None,
#     'query': 'Nuno',
#     'tweet_volume': None},
#    {'name': 'Pfizer',
#     'url': 'http://twitter.com/search?q=Pfizer',
#     'promoted_content': None,
#     'query': 'Pfizer',
#     'tweet_volume': 431938},
#    {'name': 'Bedknobs and Broomsticks',
#     'url': 'http://twitter.com/search?q=%22Bedknobs+and+Broomsticks%22',
#     'promoted_content': None,
#     'query': '%22Bedknobs+and+Broomsticks%22',
#     'tweet_volume': None},
#    {'name': 'Sandy Hook',
#     'url': 'http://twitter.com/search?q=%22Sandy+Hook%22',
#     'promoted_content': None,
#     'query': '%22Sandy+Hook%22',
#     'tweet_volume': 266434},
#    {'name': 'Cleverly',
#     'url': 'http://twitter.com/search?q=Cleverly',
#     'promoted_content': None,
#     'query': 'Cleverly',
#     'tweet_volume': None},
#    {'name': 'Wordle 480 X',
#     'url': 'http://twitter.com/search?q=%22Wordle+480+X%22',
#     'promoted_content': None,
#     'query': '%22Wordle+480+X%22',
#     'tweet_volume': None},
#    {'name': 'daily quordle 261',
#     'url': 'http://twitter.com/search?q=%22daily+quordle+261%22',
#     'promoted_content': None,
#     'query': '%22daily+quordle+261%22',
#     'tweet_volume': None},
#    {'name': 'Mo Salah',
#     'url': 'http://twitter.com/search?q=%22Mo+Salah%22',
#     'promoted_content': None,
#     'query': '%22Mo+Salah%22',
#     'tweet_volume': 41601},
#    {'name': 'Liverpool',
#     'url': 'http://twitter.com/search?q=Liverpool',
#     'promoted_content': None,
#     'query': 'Liverpool',
#     'tweet_volume': 176786},
#    {'name': 'Blink 182',
#     'url': 'http://twitter.com/search?q=%22Blink+182%22',
#     'promoted_content': None,
#     'query': '%22Blink+182%22',
#     'tweet_volume': 28745},
#    {'name': 'Barcelona',
#     'url': 'http://twitter.com/search?q=Barcelona',
#     'promoted_content': None,
#     'query': 'Barcelona',
#     'tweet_volume': 355074},
#    {'name': 'Pique',
#     'url': 'http://twitter.com/search?q=Pique',
#     'promoted_content': None,
#     'query': 'Pique',
#     'tweet_volume': 280691},
#    {'name': 'Champions League',
#     'url': 'http://twitter.com/search?q=%22Champions+League%22',
#     'promoted_content': None,
#     'query': '%22Champions+League%22',
#     'tweet_volume': 177178},
#    {'name': 'Rowett',
#     'url': 'http://twitter.com/search?q=Rowett',
#     'promoted_content': None,
#     'query': 'Rowett',
#     'tweet_volume': None},
#    {'name': 'Reiss Nelson',
#     'url': 'http://twitter.com/search?q=%22Reiss+Nelson%22',
#     'promoted_content': None,
#     'query': '%22Reiss+Nelson%22',
#     'tweet_volume': None},
#    {'name': 'Wasps',
#     'url': 'http://twitter.com/search?q=Wasps',
#     'promoted_content': None,
#     'query': 'Wasps',
#     'tweet_volume': None},
#    {'name': 'Europa League',
#     'url': 'http://twitter.com/search?q=%22Europa+League%22',
#     'promoted_content': None,
#     'query': '%22Europa+League%22',
#     'tweet_volume': 214435},
#    {'name': 'Odegaard',
#     'url': 'http://twitter.com/search?q=Odegaard',
#     'promoted_content': None,
#     'query': 'Odegaard',
#     'tweet_volume': None},
#    {'name': '1922 Committee',
#     'url': 'http://twitter.com/search?q=%221922+Committee%22',
#     'promoted_content': None,
#     'query': '%221922+Committee%22',
#     'tweet_volume': 27759},
#    {'name': 'Murder She Wrote',
#     'url': 'http://twitter.com/search?q=%22Murder+She+Wrote%22',
#     'promoted_content': None,
#     'query': '%22Murder+She+Wrote%22',
#     'tweet_volume': None},
#    {'name': 'Graham Norton',
#     'url': 'http://twitter.com/search?q=%22Graham+Norton%22',
#     'promoted_content': None,
#     'query': '%22Graham+Norton%22',
#     'tweet_volume': 11702},
#    {'name': 'RIP Rico',
#     'url': 'http://twitter.com/search?q=%22RIP+Rico%22',
#     'promoted_content': None,
#     'query': '%22RIP+Rico%22',
#     'tweet_volume': 40261},
#    {'name': 'Ross Wilson',
#     'url': 'http://twitter.com/search?q=%22Ross+Wilson%22',
#     'promoted_content': None,
#     'query': '%22Ross+Wilson%22',
#     'tweet_volume': None},
#    {'name': 'Up the Ra',
#     'url': 'http://twitter.com/search?q=%22Up+the+Ra%22',
#     'promoted_content': None,
#     'query': '%22Up+the+Ra%22',
#     'tweet_volume': None},
#    {'name': 'Nikolas Cruz',
#     'url': 'http://twitter.com/search?q=%22Nikolas+Cruz%22',
#     'promoted_content': None,
#     'query': '%22Nikolas+Cruz%22',
#     'tweet_volume': 11962},
#    {'name': 'Vieira',
#     'url': 'http://twitter.com/search?q=Vieira',
#     'promoted_content': None,
#     'query': 'Vieira',
#     'tweet_volume': None},
#    {'name': 'Lucy Letby',
#     'url': 'http://twitter.com/search?q=%22Lucy+Letby%22',
#     'promoted_content': None,
#     'query': '%22Lucy+Letby%22',
#     'tweet_volume': None},
#    {'name': 'Jacob Rees-Mogg',
#     'url': 'http://twitter.com/search?q=%22Jacob+Rees-Mogg%22',
#     'promoted_content': None,
#     'query': '%22Jacob+Rees-Mogg%22',
#     'tweet_volume': 39829},
#    {'name': 'Carvalho',
#     'url': 'http://twitter.com/search?q=Carvalho',
#     'promoted_content': None,
#     'query': 'Carvalho',
#     'tweet_volume': 16700},
#    {'name': 'Bob Seely',
#     'url': 'http://twitter.com/search?q=%22Bob+Seely%22',
#     'promoted_content': None,
#     'query': '%22Bob+Seely%22',
#     'tweet_volume': None},
#    {'name': 'King Charles',
#     'url': 'http://twitter.com/search?q=%22King+Charles%22',
#     'promoted_content': None,
#     'query': '%22King+Charles%22',
#     'tweet_volume': 20506},
#    {'name': 'Emma',
#     'url': 'http://twitter.com/search?q=Emma',
#     'promoted_content': None,
#     'query': 'Emma',
#     'tweet_volume': 69023},
#    {'name': 'Xavi',
#     'url': 'http://twitter.com/search?q=Xavi',
#     'promoted_content': None,
#     'query': 'Xavi',
#     'tweet_volume': 260952},
#    {'name': 'Jimmy Carr',
#     'url': 'http://twitter.com/search?q=%22Jimmy+Carr%22',
#     'promoted_content': None,
#     'query': '%22Jimmy+Carr%22',
#     'tweet_volume': None},
#    {'name': 'Mbappe',
#     'url': 'http://twitter.com/search?q=Mbappe',
#     'promoted_content': None,
#     'query': 'Mbappe',
#     'tweet_volume': 66635}],
#   'as_of': '2022-10-13T16:42:51Z',
#   'created_at': '2022-10-11T06:22:16Z',
#   'locations': [{'name': 'London', 'woeid': 44418}]}]

# %%
# View output as a DataFrame.
# Import Pandas.
import pandas as pd

# Create a DataFrame.
london_trends_pd = pd.DataFrame(london_trends[0]['trends'])

# View the DataFrame.
london_trends_pd
# Out:
#                         name  \
# 0               Old Trafford
# 1              #construction
# 2                  Channel 4
# 3                    Rangers
# 4                 Alex Jones
# 5                    #ranliv
# 6                      #PMQs
# 7                      Barca
# 8                    Firmino
# 9                     Napoli
# 10            #thursdayvibes
# 11                     Ibrox
# 12           Angela Lansbury
# 13                   Goldson
# 14                      Nuno
# 15                    Pfizer
# 16  Bedknobs and Broomsticks
# 17                Sandy Hook
# 18                  Cleverly
# 19              Wordle 480 X
# 20         daily quordle 261
# 21                  Mo Salah
# 22                 Liverpool
# 23                 Blink 182
# 24                 Barcelona
# 25                     Pique
# 26          Champions League
# 27                    Rowett
# 28              Reiss Nelson
# 29                     Wasps
# 30             Europa League
# 31                  Odegaard
# 32            1922 Committee
# 33          Murder She Wrote
# 34             Graham Norton
# 35                  RIP Rico
# 36               Ross Wilson
# 37                 Up the Ra
# 38              Nikolas Cruz
# 39                    Vieira
# 40                Lucy Letby
# 41           Jacob Rees-Mogg
# 42                  Carvalho
# 43                 Bob Seely
# 44              King Charles
# 45                      Emma
# 46                      Xavi
# 47                Jimmy Carr
# 48                    Mbappe
#
#                                                   url promoted_content  \
# 0      http://twitter.com/search?q=%22Old+Trafford%22             None
# 1         http://twitter.com/search?q=%23construction             None
# 2         http://twitter.com/search?q=%22Channel+4%22             None
# 3                 http://twitter.com/search?q=Rangers             None
# 4        http://twitter.com/search?q=%22Alex+Jones%22             None
# 5               http://twitter.com/search?q=%23ranliv             None
# 6                 http://twitter.com/search?q=%23PMQs             None
# 7                   http://twitter.com/search?q=Barca             None
# 8                 http://twitter.com/search?q=Firmino             None
# 9                  http://twitter.com/search?q=Napoli             None
# 10       http://twitter.com/search?q=%23thursdayvibes             None
# 11                  http://twitter.com/search?q=Ibrox             None
# 12  http://twitter.com/search?q=%22Angela+Lansbury%22             None
# 13                http://twitter.com/search?q=Goldson             None
# 14                   http://twitter.com/search?q=Nuno             None
# 15                 http://twitter.com/search?q=Pfizer             None
# 16  http://twitter.com/search?q=%22Bedknobs+and+Br...             None
# 17       http://twitter.com/search?q=%22Sandy+Hook%22             None
# 18               http://twitter.com/search?q=Cleverly             None
# 19     http://twitter.com/search?q=%22Wordle+480+X%22             None
# 20  http://twitter.com/search?q=%22daily+quordle+2...             None
# 21         http://twitter.com/search?q=%22Mo+Salah%22             None
# 22              http://twitter.com/search?q=Liverpool             None
# 23        http://twitter.com/search?q=%22Blink+182%22             None
# 24              http://twitter.com/search?q=Barcelona             None
# 25                  http://twitter.com/search?q=Pique             None
# 26  http://twitter.com/search?q=%22Champions+Leagu...             None
# 27                 http://twitter.com/search?q=Rowett             None
# 28     http://twitter.com/search?q=%22Reiss+Nelson%22             None
# 29                  http://twitter.com/search?q=Wasps             None
# 30    http://twitter.com/search?q=%22Europa+League%22             None
# 31               http://twitter.com/search?q=Odegaard             None
# 32   http://twitter.com/search?q=%221922+Committee%22             None
# 33  http://twitter.com/search?q=%22Murder+She+Wrot...             None
# 34    http://twitter.com/search?q=%22Graham+Norton%22             None
# 35         http://twitter.com/search?q=%22RIP+Rico%22             None
# 36      http://twitter.com/search?q=%22Ross+Wilson%22             None
# 37        http://twitter.com/search?q=%22Up+the+Ra%22             None
# 38     http://twitter.com/search?q=%22Nikolas+Cruz%22             None
# 39                 http://twitter.com/search?q=Vieira             None
# 40       http://twitter.com/search?q=%22Lucy+Letby%22             None
# 41  http://twitter.com/search?q=%22Jacob+Rees-Mogg%22             None
# 42               http://twitter.com/search?q=Carvalho             None
# 43        http://twitter.com/search?q=%22Bob+Seely%22             None
# 44     http://twitter.com/search?q=%22King+Charles%22             None
# 45                   http://twitter.com/search?q=Emma             None
# 46                   http://twitter.com/search?q=Xavi             None
# 47       http://twitter.com/search?q=%22Jimmy+Carr%22             None
# 48                 http://twitter.com/search?q=Mbappe             None
#
#                              query  tweet_volume
# 0               %22Old+Trafford%22           NaN
# 1                  %23construction           NaN
# 2                  %22Channel+4%22       35949.0
# 3                          Rangers      124944.0
# 4                 %22Alex+Jones%22      600808.0
# 5                        %23ranliv       38364.0
# 6                          %23PMQs       28907.0
# 7                            Barca      404779.0
# 8                          Firmino       52008.0
# 9                           Napoli       92238.0
# 10                %23thursdayvibes       12665.0
# 11                           Ibrox       14159.0
# 12           %22Angela+Lansbury%22       46998.0
# 13                         Goldson           NaN
# 14                            Nuno           NaN
# 15                          Pfizer      431938.0
# 16  %22Bedknobs+and+Broomsticks%22           NaN
# 17                %22Sandy+Hook%22      266434.0
# 18                        Cleverly           NaN
# 19              %22Wordle+480+X%22           NaN
# 20         %22daily+quordle+261%22           NaN
# 21                  %22Mo+Salah%22       41601.0
# 22                       Liverpool      176786.0
# 23                 %22Blink+182%22       28745.0
# 24                       Barcelona      355074.0
# 25                           Pique      280691.0
# 26          %22Champions+League%22      177178.0
# 27                          Rowett           NaN
# 28              %22Reiss+Nelson%22           NaN
# 29                           Wasps           NaN
# 30             %22Europa+League%22      214435.0
# 31                        Odegaard           NaN
# 32            %221922+Committee%22       27759.0
# 33          %22Murder+She+Wrote%22           NaN
# 34             %22Graham+Norton%22       11702.0
# 35                  %22RIP+Rico%22       40261.0
# 36               %22Ross+Wilson%22           NaN
# 37                 %22Up+the+Ra%22           NaN
# 38              %22Nikolas+Cruz%22       11962.0
# 39                          Vieira           NaN
# 40                %22Lucy+Letby%22           NaN
# 41           %22Jacob+Rees-Mogg%22       39829.0
# 42                        Carvalho       16700.0
# 43                 %22Bob+Seely%22           NaN
# 44              %22King+Charles%22       20506.0
# 45                            Emma       69023.0
# 46                            Xavi      260952.0
# 47                %22Jimmy+Carr%22           NaN
# 48                          Mbappe       66635.0

# %%
# Narrow the list down to 50,000 tweets.
london_trends_over50k_pd = london_trends_pd[ny_trends_pd['tweet_volume'] > 50000]\
.sort_values('tweet_volume', ascending=False)

# View the output.
print(london_trends_over50k_pd.shape)
london_trends_over50k_pd
# Out:
# (10, 5)
# /var/folders/td/h_nv_xmx2dj31ym4jqxrtjs00000gn/T/ipykernel_14637/2023880805.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   london_trends_over50k_pd = london_trends_pd[ny_trends_pd['tweet_volume'] > 50000]\
#                name                                                url  \
# 3           Rangers                http://twitter.com/search?q=Rangers
# 12  Angela Lansbury  http://twitter.com/search?q=%22Angela+Lansbury%22
# 41  Jacob Rees-Mogg  http://twitter.com/search?q=%22Jacob+Rees-Mogg%22
# 5           #ranliv              http://twitter.com/search?q=%23ranliv
# 11            Ibrox                  http://twitter.com/search?q=Ibrox
# 1     #construction        http://twitter.com/search?q=%23construction
# 13          Goldson                http://twitter.com/search?q=Goldson
# 19     Wordle 480 X     http://twitter.com/search?q=%22Wordle+480+X%22
# 31         Odegaard               http://twitter.com/search?q=Odegaard
# 47       Jimmy Carr       http://twitter.com/search?q=%22Jimmy+Carr%22
#
#    promoted_content                  query  tweet_volume
# 3              None                Rangers      124944.0
# 12             None  %22Angela+Lansbury%22       46998.0
# 41             None  %22Jacob+Rees-Mogg%22       39829.0
# 5              None              %23ranliv       38364.0
# 11             None                  Ibrox       14159.0
# 1              None        %23construction           NaN
# 13             None                Goldson           NaN
# 19             None     %22Wordle+480+X%22           NaN
# 31             None               Odegaard           NaN
# 47             None       %22Jimmy+Carr%22           NaN

# %%
# Save output as CSV file.
ny_trends_over50k_pd.to_csv('ny_over50k.csv', index=False)

# %%
# Save output as CSV file.
london_trends_over50k_pd.to_csv('london_over50k.csv', index=False)

# %%
# Find the common trends between New York and London

# Find common topics.
ny_trends_list = [trend['name'] for trend in ny_trends[0]['trends']]
london_trends_list = [trend['name'] for trend in london_trends[0]['trends']]

# View the output.
print(ny_trends_list)
print(london_trends_list)
# Out:
# ['Sabres', 'Cartoon Network', 'Parkland', '#AMAs', 'Dan Snyder', '#SheHulk', 'Nikolas Cruz', '#PaulSilva', '#thursdayvibes', 'Voting for a Republican', '#inflation', 'Favorite Pop Duo or Group', 'Iraq', 'Social Security', 'Beyoncé and Rihanna', 'Ms. Marvel', 'Carlos Correa', 'Isaiah Joe', 'Death Penalty', 'Gallardo', 'Jerry Jones', 'Happy 247th', 'Jaspers', 'Goodell', 'Woodman', 'Westbrook', '$SPY', 'William Jackson', 'Ginuwine', 'Skaar', 'Life in Prison', 'Macron', 'Graham Norton', 'Alex Hamzy', 'Bassey', 'Nino Brown', 'Dan Synder', 'Kroger', 'cheol', 'Albertsons', 'Happy Friday Eve', 'COLA', 'Gohmert', 'Board of Trustees', 'Rittenhouse', 'Trump Organization', 'Core CPI', 'Beau', 'Thirsty Thursday', 'Korkmaz']
# ['Old Trafford', '#construction', 'Channel 4', 'Rangers', 'Alex Jones', '#ranliv', '#PMQs', 'Barca', 'Firmino', 'Napoli', '#thursdayvibes', 'Ibrox', 'Angela Lansbury', 'Goldson', 'Nuno', 'Pfizer', 'Bedknobs and Broomsticks', 'Sandy Hook', 'Cleverly', 'Wordle 480 X', 'daily quordle 261', 'Mo Salah', 'Liverpool', 'Blink 182', 'Barcelona', 'Pique', 'Champions League', 'Rowett', 'Reiss Nelson', 'Wasps', 'Europa League', 'Odegaard', '1922 Committee', 'Murder She Wrote', 'Graham Norton', 'RIP Rico', 'Ross Wilson', 'Up the Ra', 'Nikolas Cruz', 'Vieira', 'Lucy Letby', 'Jacob Rees-Mogg', 'Carvalho', 'Bob Seely', 'King Charles', 'Emma', 'Xavi', 'Jimmy Carr', 'Mbappe']

# %%
# Find common trends between cities.
ny_trends_set = set(ny_trends_list)
london_trends_set = set(london_trends_list)

# Set the variable.
common_trends = ny_trends_set.intersection(london_trends_set)

# View the output.
print(common_trends)
# Out:
# {'Nikolas Cruz', 'Graham Norton', '#thursdayvibes'}

# %%
# Import JSON.
import json

# Search for NY (woeid = 2459115).
ny_trends = twitter_api.trends.place(_id=2459115)

# View JSON output.
print (json.dumps(ny_trends, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "Sabres",
#                 "url": "http://twitter.com/search?q=Sabres",
#                 "promoted_content": null,
#                 "query": "Sabres",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#Isles",
#                 "url": "http://twitter.com/search?q=%23Isles",
#                 "promoted_content": null,
#                 "query": "%23Isles",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Cartoon Network",
#                 "url": "http://twitter.com/search?q=%22Cartoon+Network%22",
#                 "promoted_content": null,
#                 "query": "%22Cartoon+Network%22",
#                 "tweet_volume": 111745
#             },
#             {
#                 "name": "#AMAs",
#                 "url": "http://twitter.com/search?q=%23AMAs",
#                 "promoted_content": null,
#                 "query": "%23AMAs",
#                 "tweet_volume": 1060916
#             },
#             {
#                 "name": "Parkland",
#                 "url": "http://twitter.com/search?q=Parkland",
#                 "promoted_content": null,
#                 "query": "Parkland",
#                 "tweet_volume": 35718
#             },
#             {
#                 "name": "#SheHulk",
#                 "url": "http://twitter.com/search?q=%23SheHulk",
#                 "promoted_content": null,
#                 "query": "%23SheHulk",
#                 "tweet_volume": 98352
#             },
#             {
#                 "name": "Dan Snyder",
#                 "url": "http://twitter.com/search?q=%22Dan+Snyder%22",
#                 "promoted_content": null,
#                 "query": "%22Dan+Snyder%22",
#                 "tweet_volume": 10045
#             },
#             {
#                 "name": "Nikolas Cruz",
#                 "url": "http://twitter.com/search?q=%22Nikolas+Cruz%22",
#                 "promoted_content": null,
#                 "query": "%22Nikolas+Cruz%22",
#                 "tweet_volume": 12706
#             },
#             {
#                 "name": "#PaulSilva",
#                 "url": "http://twitter.com/search?q=%23PaulSilva",
#                 "promoted_content": null,
#                 "query": "%23PaulSilva",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#thursdayvibes",
#                 "url": "http://twitter.com/search?q=%23thursdayvibes",
#                 "promoted_content": null,
#                 "query": "%23thursdayvibes",
#                 "tweet_volume": 12989
#             },
#             {
#                 "name": "Voting for a Republican",
#                 "url": "http://twitter.com/search?q=%22Voting+for+a+Republican%22",
#                 "promoted_content": null,
#                 "query": "%22Voting+for+a+Republican%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Favorite Pop Duo or Group",
#                 "url": "http://twitter.com/search?q=%22Favorite+Pop+Duo+or+Group%22",
#                 "promoted_content": null,
#                 "query": "%22Favorite+Pop+Duo+or+Group%22",
#                 "tweet_volume": 538487
#             },
#             {
#                 "name": "Iraq",
#                 "url": "http://twitter.com/search?q=Iraq",
#                 "promoted_content": null,
#                 "query": "Iraq",
#                 "tweet_volume": 76042
#             },
#             {
#                 "name": "Ms. Marvel",
#                 "url": "http://twitter.com/search?q=%22Ms.+Marvel%22",
#                 "promoted_content": null,
#                 "query": "%22Ms.+Marvel%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Social Security",
#                 "url": "http://twitter.com/search?q=%22Social+Security%22",
#                 "promoted_content": null,
#                 "query": "%22Social+Security%22",
#                 "tweet_volume": 122053
#             },
#             {
#                 "name": "Beyonc\u00e9 and Rihanna",
#                 "url": "http://twitter.com/search?q=%22Beyonc%C3%A9+and+Rihanna%22",
#                 "promoted_content": null,
#                 "query": "%22Beyonc%C3%A9+and+Rihanna%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Gallardo",
#                 "url": "http://twitter.com/search?q=Gallardo",
#                 "promoted_content": null,
#                 "query": "Gallardo",
#                 "tweet_volume": 112737
#             },
#             {
#                 "name": "Moon Knight",
#                 "url": "http://twitter.com/search?q=%22Moon+Knight%22",
#                 "promoted_content": null,
#                 "query": "%22Moon+Knight%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Death Penalty",
#                 "url": "http://twitter.com/search?q=%22Death+Penalty%22",
#                 "promoted_content": null,
#                 "query": "%22Death+Penalty%22",
#                 "tweet_volume": 21760
#             },
#             {
#                 "name": "Jerry Jones",
#                 "url": "http://twitter.com/search?q=%22Jerry+Jones%22",
#                 "promoted_content": null,
#                 "query": "%22Jerry+Jones%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Correa",
#                 "url": "http://twitter.com/search?q=Correa",
#                 "promoted_content": null,
#                 "query": "Correa",
#                 "tweet_volume": 25337
#             },
#             {
#                 "name": "Isaiah Joe",
#                 "url": "http://twitter.com/search?q=%22Isaiah+Joe%22",
#                 "promoted_content": null,
#                 "query": "%22Isaiah+Joe%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Trump Organization II",
#                 "url": "http://twitter.com/search?q=%22Trump+Organization+II%22",
#                 "promoted_content": null,
#                 "query": "%22Trump+Organization+II%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Jaspers",
#                 "url": "http://twitter.com/search?q=Jaspers",
#                 "promoted_content": null,
#                 "query": "Jaspers",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Happy 247th",
#                 "url": "http://twitter.com/search?q=%22Happy+247th%22",
#                 "promoted_content": null,
#                 "query": "%22Happy+247th%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Woodman",
#                 "url": "http://twitter.com/search?q=Woodman",
#                 "promoted_content": null,
#                 "query": "Woodman",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Westbrook",
#                 "url": "http://twitter.com/search?q=Westbrook",
#                 "promoted_content": null,
#                 "query": "Westbrook",
#                 "tweet_volume": 12682
#             },
#             {
#                 "name": "Goodell",
#                 "url": "http://twitter.com/search?q=Goodell",
#                 "promoted_content": null,
#                 "query": "Goodell",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Ginuwine",
#                 "url": "http://twitter.com/search?q=Ginuwine",
#                 "promoted_content": null,
#                 "query": "Ginuwine",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "$SPY",
#                 "url": "http://twitter.com/search?q=%24SPY",
#                 "promoted_content": null,
#                 "query": "%24SPY",
#                 "tweet_volume": 20855
#             },
#             {
#                 "name": "William Jackson",
#                 "url": "http://twitter.com/search?q=%22William+Jackson%22",
#                 "promoted_content": null,
#                 "query": "%22William+Jackson%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Skaar",
#                 "url": "http://twitter.com/search?q=Skaar",
#                 "promoted_content": null,
#                 "query": "Skaar",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Macron",
#                 "url": "http://twitter.com/search?q=Macron",
#                 "promoted_content": null,
#                 "query": "Macron",
#                 "tweet_volume": 192113
#             },
#             {
#                 "name": "Albertsons",
#                 "url": "http://twitter.com/search?q=Albertsons",
#                 "promoted_content": null,
#                 "query": "Albertsons",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Kroger",
#                 "url": "http://twitter.com/search?q=Kroger",
#                 "promoted_content": null,
#                 "query": "Kroger",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Alex Hamzy",
#                 "url": "http://twitter.com/search?q=%22Alex+Hamzy%22",
#                 "promoted_content": null,
#                 "query": "%22Alex+Hamzy%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Graham Norton",
#                 "url": "http://twitter.com/search?q=%22Graham+Norton%22",
#                 "promoted_content": null,
#                 "query": "%22Graham+Norton%22",
#                 "tweet_volume": 11867
#             },
#             {
#                 "name": "Dan Synder",
#                 "url": "http://twitter.com/search?q=%22Dan+Synder%22",
#                 "promoted_content": null,
#                 "query": "%22Dan+Synder%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Bassey",
#                 "url": "http://twitter.com/search?q=Bassey",
#                 "promoted_content": null,
#                 "query": "Bassey",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "The Watcher",
#                 "url": "http://twitter.com/search?q=%22The+Watcher%22",
#                 "promoted_content": null,
#                 "query": "%22The+Watcher%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Rittenhouse",
#                 "url": "http://twitter.com/search?q=Rittenhouse",
#                 "promoted_content": null,
#                 "query": "Rittenhouse",
#                 "tweet_volume": 13656
#             },
#             {
#                 "name": "COLA",
#                 "url": "http://twitter.com/search?q=COLA",
#                 "promoted_content": null,
#                 "query": "COLA",
#                 "tweet_volume": 57121
#             },
#             {
#                 "name": "Nino Brown",
#                 "url": "http://twitter.com/search?q=%22Nino+Brown%22",
#                 "promoted_content": null,
#                 "query": "%22Nino+Brown%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Life in Prison",
#                 "url": "http://twitter.com/search?q=%22Life+in+Prison%22",
#                 "promoted_content": null,
#                 "query": "%22Life+in+Prison%22",
#                 "tweet_volume": 14049
#             },
#             {
#                 "name": "cheol",
#                 "url": "http://twitter.com/search?q=cheol",
#                 "promoted_content": null,
#                 "query": "cheol",
#                 "tweet_volume": 33263
#             },
#             {
#                 "name": "Happy Friday Eve",
#                 "url": "http://twitter.com/search?q=%22Happy+Friday+Eve%22",
#                 "promoted_content": null,
#                 "query": "%22Happy+Friday+Eve%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Tremors",
#                 "url": "http://twitter.com/search?q=Tremors",
#                 "promoted_content": null,
#                 "query": "Tremors",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Gohmert",
#                 "url": "http://twitter.com/search?q=Gohmert",
#                 "promoted_content": null,
#                 "query": "Gohmert",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Broward",
#                 "url": "http://twitter.com/search?q=Broward",
#                 "promoted_content": null,
#                 "query": "Broward",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "colleen hoover",
#                 "url": "http://twitter.com/search?q=%22colleen+hoover%22",
#                 "promoted_content": null,
#                 "query": "%22colleen+hoover%22",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2022-10-13T16:56:45Z",
#         "created_at": "2022-10-09T06:33:23Z",
#         "locations": [
#             {
#                 "name": "New York",
#                 "woeid": 2459115
#             }
#         ]
#     }
# ]

# %%
# Import JSON.
import json

# Search for London (woeid = 44418).
london_trends = twitter_api.trends.place(_id=44418)

# View JSON output.
print (json.dumps(london_trends, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "Macron",
#                 "url": "http://twitter.com/search?q=Macron",
#                 "promoted_content": null,
#                 "query": "Macron",
#                 "tweet_volume": 192113
#             },
#             {
#                 "name": "Old Trafford",
#                 "url": "http://twitter.com/search?q=%22Old+Trafford%22",
#                 "promoted_content": null,
#                 "query": "%22Old+Trafford%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Rangers",
#                 "url": "http://twitter.com/search?q=Rangers",
#                 "promoted_content": null,
#                 "query": "Rangers",
#                 "tweet_volume": 125262
#             },
#             {
#                 "name": "Alex Jones",
#                 "url": "http://twitter.com/search?q=%22Alex+Jones%22",
#                 "promoted_content": null,
#                 "query": "%22Alex+Jones%22",
#                 "tweet_volume": 605328
#             },
#             {
#                 "name": "#ranliv",
#                 "url": "http://twitter.com/search?q=%23ranliv",
#                 "promoted_content": null,
#                 "query": "%23ranliv",
#                 "tweet_volume": 38371
#             },
#             {
#                 "name": "#PMQs",
#                 "url": "http://twitter.com/search?q=%23PMQs",
#                 "promoted_content": null,
#                 "query": "%23PMQs",
#                 "tweet_volume": 29000
#             },
#             {
#                 "name": "Barca",
#                 "url": "http://twitter.com/search?q=Barca",
#                 "promoted_content": null,
#                 "query": "Barca",
#                 "tweet_volume": 406363
#             },
#             {
#                 "name": "Bobby",
#                 "url": "http://twitter.com/search?q=Bobby",
#                 "promoted_content": null,
#                 "query": "Bobby",
#                 "tweet_volume": 63279
#             },
#             {
#                 "name": "Napoli",
#                 "url": "http://twitter.com/search?q=Napoli",
#                 "promoted_content": null,
#                 "query": "Napoli",
#                 "tweet_volume": 92479
#             },
#             {
#                 "name": "#thursdayvibes",
#                 "url": "http://twitter.com/search?q=%23thursdayvibes",
#                 "promoted_content": null,
#                 "query": "%23thursdayvibes",
#                 "tweet_volume": 12989
#             },
#             {
#                 "name": "#WorldSightDay",
#                 "url": "http://twitter.com/search?q=%23WorldSightDay",
#                 "promoted_content": null,
#                 "query": "%23WorldSightDay",
#                 "tweet_volume": 149093
#             },
#             {
#                 "name": "Ibrox",
#                 "url": "http://twitter.com/search?q=Ibrox",
#                 "promoted_content": null,
#                 "query": "Ibrox",
#                 "tweet_volume": 14203
#             },
#             {
#                 "name": "Angela Lansbury",
#                 "url": "http://twitter.com/search?q=%22Angela+Lansbury%22",
#                 "promoted_content": null,
#                 "query": "%22Angela+Lansbury%22",
#                 "tweet_volume": 47252
#             },
#             {
#                 "name": "Goldson",
#                 "url": "http://twitter.com/search?q=Goldson",
#                 "promoted_content": null,
#                 "query": "Goldson",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Nuno",
#                 "url": "http://twitter.com/search?q=Nuno",
#                 "promoted_content": null,
#                 "query": "Nuno",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Pfizer",
#                 "url": "http://twitter.com/search?q=Pfizer",
#                 "promoted_content": null,
#                 "query": "Pfizer",
#                 "tweet_volume": 435494
#             },
#             {
#                 "name": "Bedknobs and Broomsticks",
#                 "url": "http://twitter.com/search?q=%22Bedknobs+and+Broomsticks%22",
#                 "promoted_content": null,
#                 "query": "%22Bedknobs+and+Broomsticks%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Sandy Hook",
#                 "url": "http://twitter.com/search?q=%22Sandy+Hook%22",
#                 "promoted_content": null,
#                 "query": "%22Sandy+Hook%22",
#                 "tweet_volume": 267603
#             },
#             {
#                 "name": "Cleverly",
#                 "url": "http://twitter.com/search?q=Cleverly",
#                 "promoted_content": null,
#                 "query": "Cleverly",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "wordle 480 x",
#                 "url": "http://twitter.com/search?q=%22wordle+480+x%22",
#                 "promoted_content": null,
#                 "query": "%22wordle+480+x%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "daily quordle 261",
#                 "url": "http://twitter.com/search?q=%22daily+quordle+261%22",
#                 "promoted_content": null,
#                 "query": "%22daily+quordle+261%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Mo Salah",
#                 "url": "http://twitter.com/search?q=%22Mo+Salah%22",
#                 "promoted_content": null,
#                 "query": "%22Mo+Salah%22",
#                 "tweet_volume": 41738
#             },
#             {
#                 "name": "Liverpool",
#                 "url": "http://twitter.com/search?q=Liverpool",
#                 "promoted_content": null,
#                 "query": "Liverpool",
#                 "tweet_volume": 177583
#             },
#             {
#                 "name": "Barcelona",
#                 "url": "http://twitter.com/search?q=Barcelona",
#                 "promoted_content": null,
#                 "query": "Barcelona",
#                 "tweet_volume": 356805
#             },
#             {
#                 "name": "Blink 182",
#                 "url": "http://twitter.com/search?q=%22Blink+182%22",
#                 "promoted_content": null,
#                 "query": "%22Blink+182%22",
#                 "tweet_volume": 29000
#             },
#             {
#                 "name": "Pique",
#                 "url": "http://twitter.com/search?q=Pique",
#                 "promoted_content": null,
#                 "query": "Pique",
#                 "tweet_volume": 281620
#             },
#             {
#                 "name": "Champions League",
#                 "url": "http://twitter.com/search?q=%22Champions+League%22",
#                 "promoted_content": null,
#                 "query": "%22Champions+League%22",
#                 "tweet_volume": 177169
#             },
#             {
#                 "name": "Rowett",
#                 "url": "http://twitter.com/search?q=Rowett",
#                 "promoted_content": null,
#                 "query": "Rowett",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Reiss Nelson",
#                 "url": "http://twitter.com/search?q=%22Reiss+Nelson%22",
#                 "promoted_content": null,
#                 "query": "%22Reiss+Nelson%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Wasps",
#                 "url": "http://twitter.com/search?q=Wasps",
#                 "promoted_content": null,
#                 "query": "Wasps",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Europa League",
#                 "url": "http://twitter.com/search?q=%22Europa+League%22",
#                 "promoted_content": null,
#                 "query": "%22Europa+League%22",
#                 "tweet_volume": 216804
#             },
#             {
#                 "name": "1922 Committee",
#                 "url": "http://twitter.com/search?q=%221922+Committee%22",
#                 "promoted_content": null,
#                 "query": "%221922+Committee%22",
#                 "tweet_volume": 27962
#             },
#             {
#                 "name": "Emma",
#                 "url": "http://twitter.com/search?q=Emma",
#                 "promoted_content": null,
#                 "query": "Emma",
#                 "tweet_volume": 69907
#             },
#             {
#                 "name": "Graham Norton",
#                 "url": "http://twitter.com/search?q=%22Graham+Norton%22",
#                 "promoted_content": null,
#                 "query": "%22Graham+Norton%22",
#                 "tweet_volume": 11867
#             },
#             {
#                 "name": "RIP Rico",
#                 "url": "http://twitter.com/search?q=%22RIP+Rico%22",
#                 "promoted_content": null,
#                 "query": "%22RIP+Rico%22",
#                 "tweet_volume": 40819
#             },
#             {
#                 "name": "Up the Ra",
#                 "url": "http://twitter.com/search?q=%22Up+the+Ra%22",
#                 "promoted_content": null,
#                 "query": "%22Up+the+Ra%22",
#                 "tweet_volume": 10064
#             },
#             {
#                 "name": "Nikolas Cruz",
#                 "url": "http://twitter.com/search?q=%22Nikolas+Cruz%22",
#                 "promoted_content": null,
#                 "query": "%22Nikolas+Cruz%22",
#                 "tweet_volume": 12654
#             },
#             {
#                 "name": "Vieira",
#                 "url": "http://twitter.com/search?q=Vieira",
#                 "promoted_content": null,
#                 "query": "Vieira",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Lucy Letby",
#                 "url": "http://twitter.com/search?q=%22Lucy+Letby%22",
#                 "promoted_content": null,
#                 "query": "%22Lucy+Letby%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Ross Wilson",
#                 "url": "http://twitter.com/search?q=%22Ross+Wilson%22",
#                 "promoted_content": null,
#                 "query": "%22Ross+Wilson%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Jacob Rees-Mogg",
#                 "url": "http://twitter.com/search?q=%22Jacob+Rees-Mogg%22",
#                 "promoted_content": null,
#                 "query": "%22Jacob+Rees-Mogg%22",
#                 "tweet_volume": 40123
#             },
#             {
#                 "name": "Carvalho",
#                 "url": "http://twitter.com/search?q=Carvalho",
#                 "promoted_content": null,
#                 "query": "Carvalho",
#                 "tweet_volume": 16862
#             },
#             {
#                 "name": "Bob Seely",
#                 "url": "http://twitter.com/search?q=%22Bob+Seely%22",
#                 "promoted_content": null,
#                 "query": "%22Bob+Seely%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Xavi",
#                 "url": "http://twitter.com/search?q=Xavi",
#                 "promoted_content": null,
#                 "query": "Xavi",
#                 "tweet_volume": 262116
#             },
#             {
#                 "name": "Odegaard",
#                 "url": "http://twitter.com/search?q=Odegaard",
#                 "promoted_content": null,
#                 "query": "Odegaard",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "King Charles",
#                 "url": "http://twitter.com/search?q=%22King+Charles%22",
#                 "promoted_content": null,
#                 "query": "%22King+Charles%22",
#                 "tweet_volume": 20694
#             },
#             {
#                 "name": "Rihanna",
#                 "url": "http://twitter.com/search?q=Rihanna",
#                 "promoted_content": null,
#                 "query": "Rihanna",
#                 "tweet_volume": 37863
#             },
#             {
#                 "name": "Jimmy Carr",
#                 "url": "http://twitter.com/search?q=%22Jimmy+Carr%22",
#                 "promoted_content": null,
#                 "query": "%22Jimmy+Carr%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "HARVEY ELLIOTT",
#                 "url": "http://twitter.com/search?q=%22HARVEY+ELLIOTT%22",
#                 "promoted_content": null,
#                 "query": "%22HARVEY+ELLIOTT%22",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2022-10-13T16:56:41Z",
#         "created_at": "2022-10-09T06:33:23Z",
#         "locations": [
#             {
#                 "name": "London",
#                 "woeid": 44418
#             }
#         ]
#     }
# ]

# %%
# Search Twitter for #Bitcoin and print the output with and json.dumps() and indent of 4.

# %%
# Search for a common trend(s).
q = '#Bitcoin'

# Set count to 100.
Count = 100

# %%
# Read some tweets.
search_results = twitter_api.search.tweets(q=q, count=100)

statuses = search_results['statuses']

# %%
for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

print(json.dumps(statuses[1], indent=1))
# Out:
# Length of statuses 83
# Length of statuses 148
# Length of statuses 148
# {
#  "created_at": "Thu Oct 13 16:57:57 +0000 2022",
#  "id": 1580603760245895168,
#  "id_str": "1580603760245895168",
#  "text": "RT @PMorival: #GroveToken It's a big boys game right now,  only the paper hands will suffer the consequences.#Bitcoin #cryptocurrency #BNB\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "GroveToken",
#     "indices": [
#      14,
#      25
#     ]
#    },
#    {
#     "text": "Bitcoin",
#     "indices": [
#      109,
#      117
#     ]
#    },
#    {
#     "text": "cryptocurrency",
#     "indices": [
#      118,
#      133
#     ]
#    },
#    {
#     "text": "BNB",
#     "indices": [
#      134,
#      138
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "PMorival",
#     "name": "Iwillmakeit",
#     "id": 2651763751,
#     "id_str": "2651763751",
#     "indices": [
#      3,
#      12
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 1409774190274789378,
#   "id_str": "1409774190274789378",
#   "name": "Ed Griffiths",
#   "screen_name": "EdGriff79780739",
#   "location": "Totnes, England",
#   "description": "Person",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 60,
#   "friends_count": 80,
#   "listed_count": 5,
#   "created_at": "Tue Jun 29 07:23:02 +0000 2021",
#   "favourites_count": 4119,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 3299,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1489312778808664072/0bYbMzHw_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1489312778808664072/0bYbMzHw_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1409774190274789378/1625134742",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none",
#   "withheld_in_countries": []
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Thu Oct 13 15:42:04 +0000 2022",
#   "id": 1580584665689096194,
#   "id_str": "1580584665689096194",
#   "text": "#GroveToken It's a big boys game right now,  only the paper hands will suffer the consequences.#Bitcoin\u2026 https://t.co/jGO850qwan",
#   "truncated": true,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "GroveToken",
#      "indices": [
#       0,
#       11
#      ]
#     },
#     {
#      "text": "Bitcoin",
#      "indices": [
#       95,
#       103
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/jGO850qwan",
#      "expanded_url": "https://twitter.com/i/web/status/1580584665689096194",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       105,
#       128
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 2651763751,
#    "id_str": "2651763751",
#    "name": "Iwillmakeit",
#    "screen_name": "PMorival",
#    "location": "",
#    "description": "Grove Token holder and believer. NFA",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 226,
#    "friends_count": 91,
#    "listed_count": 2,
#    "created_at": "Wed Jul 16 18:52:21 +0000 2014",
#    "favourites_count": 2380,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 1804,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C0DEED",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1355402790479265792/QgCb29eG_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1355402790479265792/QgCb29eG_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2651763751/1661023165",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none",
#    "withheld_in_countries": []
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 15,
#   "favorite_count": 43,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 15,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# Check statuses.
t = statuses[0]

# Print the keys.
t.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'extended_entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %%
# Find the id.
print(t['id'])

# View the ouput in text.
print(t['text'])

# View entities.
t['entities']
# Out:
# 1580603761516765191
# RT @MMCrypto: #BITCOIN EMERGNECY!!!!! 🚨 https://t.co/C7f1SXtQiH
# {'hashtags': [{'text': 'BITCOIN', 'indices': [14, 22]}],
#  'symbols': [],
#  'user_mentions': [{'screen_name': 'MMCrypto',
#    'name': 'MMCrypto',
#    'id': 904700529988820992,
#    'id_str': '904700529988820992',
#    'indices': [3, 12]}],
#  'urls': [],
#  'media': [{'id': 1580601078088966146,
#    'id_str': '1580601078088966146',
#    'indices': [40, 63],
#    'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1580601078088966146/pu/img/wgYE3prpZufk_tRa.jpg',
#    'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1580601078088966146/pu/img/wgYE3prpZufk_tRa.jpg',
#    'url': 'https://t.co/C7f1SXtQiH',
#    'display_url': 'pic.twitter.com/C7f1SXtQiH',
#    'expanded_url': 'https://twitter.com/MMCrypto/status/1580601402988318720/video/1',
#    'type': 'photo',
#    'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#     'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#     'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#     'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#    'source_status_id': 1580601402988318720,
#    'source_status_id_str': '1580601402988318720',
#    'source_user_id': 904700529988820992,
#    'source_user_id_str': '904700529988820992'}]}
